# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from tqdm import tqdm

# %%
client_credentials = SpotifyClientCredentials(client_id = '69d5ceec0f8d42299ac8fce0969a6beb', client_secret = 'f35d4f91afc64282832550504da49790')
spotify = spotipy.Spotify(client_credentials_manager = client_credentials)

# %%
data=pd.read_excel('MSD_spotify_id.xls',header=None)

# %%
data=data[data[5]!=-999]

# %%
zero_year_data=data[data[3]==0]

# %%
results = spotify.search(q='artist:' + artist + ' track:' + track, type='track')

# %%
ll=[]
for i in tqdm(zero_year_data.iterrows()):
    results = spotify.search(q='artist:' + str(i[1][0]) + ' track:' + str(i[1][2]), type='track')
    if len(results['tracks']['items'])!=0:
        ll.append(results['tracks']['items'][0]['album']['release_date'][0:4])
    else:
        ll.append(-999)
# Out:
# 3117it [1:09:12,  1.45it/s]

# %%
zero_year_data
# Out:
#                              0                                    1  \
# 0             Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 2                 JennyAnyKind                           I Need You
# 3                       Casual                          Fear Itself
# 4        Jeff And Sheri Easter                         Ordinary Day
# 5        Tweeterfriendly Music                         Gin & Phonic
# ...                        ...                                  ...
# 9986             Don Francisco                      Genesis And Job
# 9988  Myrick "Freeze" Guillory                       Nouveau Zydeco
# 9990             Grandpa Jones      The Unforgettable Grandpa Jones
# 9992            Diamanda Galas                    The Sporting Life
# 9999             Winston Reedy                              Reality
#
#                                                 2  3                   4  \
# 0                                 Amor De Cabaret  0  TRAAADZ128F9348C2E
# 2                                 Young Boy Blues  0  TRAAAVO128F93133D4
# 3                                I Didn't Mean To  0  TRAAAAW128F429D538
# 4     The Moon And I (Ordinary Day Album Version)  0  TRAAAMO128F1481E7F
# 5                                    Drop of Rain  0  TRAAAPK128E0786D96
# ...                                           ... ..                 ...
# 9986                     Overture (Genesis & Job)  0  TRBIISJ128F14AE61C
# 9988                            Zydeco In D-Minor  0  TRBIJRN128F425F3DD
# 9990                                Down In Dixie  0  TRBIJKN12903CBF11B
# 9992                       Dark End Of The Street  0  TRBIJFO128F42990C5
# 9999                              Sentimental Man  0  TRBIJNK128F93093EC
#
#                            5
# 0     5JeyXbf7CrVQ8DqwFikN0P
# 2     5uN6oY2NGLC6GKoywHKkZA
# 3     01TR6aAKrA2cI3Z0gnCOsu
# 4     7ERvcsBBYzSHqQQqlI9xAN
# 5     6dfppQDZQ4x3fCs6N89kV3
# ...                      ...
# 9986  1IRcc7bSySQt6UF1qKK9L6
# 9988  5DqBIhTIAOUQRsmqe5f0oA
# 9990  31pxc4TDet1VWBGdwibNqD
# 9992  1pTOAsLA1VJPLe5IusBOZb
# 9999  7n0ShZeoewT4ZOJCmwHdnQ
#
# [3117 rows x 6 columns]

# %%
non_zero_year_data=data[data[3]!=0]

# %%
non_zero_year_data
# Out:
#                          0                           1  \
# 1         Planet P Project                  Pink World
# 6             The Box Tops                  Dimensions
# 7                 Adam Ant               Friend Or Foe
# 8                      Gob               Muertos Vivos
# 15           Lionel Richie      Dancing On The Ceiling
# ...                    ...                         ...
# 9994             Moonspell                Sin / Pecado
# 9995   Seventh Day Slumber  Once Upon A Shattered Life
# 9996  Blind Willie Johnson    Praise God I'm Satisfied
# 9997         It Dies Today                      Sirens
# 9998        Danny Williams                  Collection
#
#                                      2     3                   4  \
# 1                           Pink World  1984  TRAAARJ128F9320760
# 6                            Soul Deep  1969  TRAAABD128F429CF47
# 7                      Something Girls  1982  TRAAAEF128F4273421
# 8                       Face the Ashes  2007  TRAAAFD128F92F423A
# 15             Tonight Will Be Alright  1986  TRAABJV128F1460C49
# ...                                ...   ...                 ...
# 9994                    The Hanged Man  1998  TRBIJMU12903CF892B
# 9995                    Shattered Life  2005  TRBIJYB128F14AE326
# 9996            God Don't Never Change  1989  TRBIJLT12903CE7070
# 9997       One the road (to Damnation)  2006  TRBIJFB128F92ED124
# 9998  The Wonderful World Of The Young  1998  TRBIJNF128F14815A7
#
#                            5
# 1     2dISPmbjb4RKXTORd3KBVp
# 6     4yPl1mK1oluIrCwI4HInPR
# 7     0ygZMtr5JdKEk1Nn58HB0V
# 8     4cdbM6efK43Cs2PDMtzdhv
# 15    2Jr12fpsMdIM6weoUDMf9u
# ...                      ...
# 9994  3e0tyTV5FiV1bcYeRjdDz2
# 9995  2CQwzG5nbS7ys8CHSlavVg
# 9996  7N3eI4cyyIPnNEXSxt6yNp
# 9997  0MS1NrmBWaCpPLFEXV0VMZ
# 9998  62wqW6Q9eTozrruWPt9Z9i
#
# [3439 rows x 6 columns]

# %%
zero_year_data[3]=ll
# Out:
# /home/samthekiller/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
zero_year_data
# Out:
#                              0                                    1  \
# 0             Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 2                 JennyAnyKind                           I Need You
# 3                       Casual                          Fear Itself
# 4        Jeff And Sheri Easter                         Ordinary Day
# 5        Tweeterfriendly Music                         Gin & Phonic
# ...                        ...                                  ...
# 9986             Don Francisco                      Genesis And Job
# 9988  Myrick "Freeze" Guillory                       Nouveau Zydeco
# 9990             Grandpa Jones      The Unforgettable Grandpa Jones
# 9992            Diamanda Galas                    The Sporting Life
# 9999             Winston Reedy                              Reality
#
#                                                 2     3                   4  \
# 0                                 Amor De Cabaret  2016  TRAAADZ128F9348C2E
# 2                                 Young Boy Blues  2000  TRAAAVO128F93133D4
# 3                                I Didn't Mean To  1994  TRAAAAW128F429D538
# 4     The Moon And I (Ordinary Day Album Version)  2006  TRAAAMO128F1481E7F
# 5                                    Drop of Rain  2003  TRAAAPK128E0786D96
# ...                                           ...   ...                 ...
# 9986                     Overture (Genesis & Job)  1994  TRBIISJ128F14AE61C
# 9988                            Zydeco In D-Minor  1991  TRBIJRN128F425F3DD
# 9990                                Down In Dixie  2005  TRBIJKN12903CBF11B
# 9992                       Dark End Of The Street  1994  TRBIJFO128F42990C5
# 9999                              Sentimental Man  2002  TRBIJNK128F93093EC
#
#                            5
# 0     5JeyXbf7CrVQ8DqwFikN0P
# 2     5uN6oY2NGLC6GKoywHKkZA
# 3     01TR6aAKrA2cI3Z0gnCOsu
# 4     7ERvcsBBYzSHqQQqlI9xAN
# 5     6dfppQDZQ4x3fCs6N89kV3
# ...                      ...
# 9986  1IRcc7bSySQt6UF1qKK9L6
# 9988  5DqBIhTIAOUQRsmqe5f0oA
# 9990  31pxc4TDet1VWBGdwibNqD
# 9992  1pTOAsLA1VJPLe5IusBOZb
# 9999  7n0ShZeoewT4ZOJCmwHdnQ
#
# [3117 rows x 6 columns]

# %%
new_data=pd.concat([zero_year_data,non_zero_year_data])

# %%
new_data
# Out:
#                           0                                    1  \
# 0          Sonora Santanera  Las Numero 1 De La Sonora Santanera
# 2              JennyAnyKind                           I Need You
# 3                    Casual                          Fear Itself
# 4     Jeff And Sheri Easter                         Ordinary Day
# 5     Tweeterfriendly Music                         Gin & Phonic
# ...                     ...                                  ...
# 9994              Moonspell                         Sin / Pecado
# 9995    Seventh Day Slumber           Once Upon A Shattered Life
# 9996   Blind Willie Johnson             Praise God I'm Satisfied
# 9997          It Dies Today                               Sirens
# 9998         Danny Williams                           Collection
#
#                                                 2     3                   4  \
# 0                                 Amor De Cabaret  2016  TRAAADZ128F9348C2E
# 2                                 Young Boy Blues  2000  TRAAAVO128F93133D4
# 3                                I Didn't Mean To  1994  TRAAAAW128F429D538
# 4     The Moon And I (Ordinary Day Album Version)  2006  TRAAAMO128F1481E7F
# 5                                    Drop of Rain  2003  TRAAAPK128E0786D96
# ...                                           ...   ...                 ...
# 9994                               The Hanged Man  1998  TRBIJMU12903CF892B
# 9995                               Shattered Life  2005  TRBIJYB128F14AE326
# 9996                       God Don't Never Change  1989  TRBIJLT12903CE7070
# 9997                  One the road (to Damnation)  2006  TRBIJFB128F92ED124
# 9998             The Wonderful World Of The Young  1998  TRBIJNF128F14815A7
#
#                            5
# 0     5JeyXbf7CrVQ8DqwFikN0P
# 2     5uN6oY2NGLC6GKoywHKkZA
# 3     01TR6aAKrA2cI3Z0gnCOsu
# 4     7ERvcsBBYzSHqQQqlI9xAN
# 5     6dfppQDZQ4x3fCs6N89kV3
# ...                      ...
# 9994  3e0tyTV5FiV1bcYeRjdDz2
# 9995  2CQwzG5nbS7ys8CHSlavVg
# 9996  7N3eI4cyyIPnNEXSxt6yNp
# 9997  0MS1NrmBWaCpPLFEXV0VMZ
# 9998  62wqW6Q9eTozrruWPt9Z9i
#
# [6556 rows x 6 columns]

# %%
new_data.to_excel('MSD_spotify_id_non_null_year.xls',index=False,header=False)
